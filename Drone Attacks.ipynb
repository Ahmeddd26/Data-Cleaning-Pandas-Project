# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\ghour\Desktop\New folder\Data Sets\Drone Attacks\Drone Attacks\PakistanDroneAttacksWithTemp Ver 9 (October 19, 2017).csv',encoding='latin1')

# %%
df.head()
# Out:
#     S#                         Date   Time  \
# 0  1.0        Friday, June 18, 2004  22:00
# 1  2.0         Sunday, May 08, 2005  23:30
# 2  3.0  Thursday, December 01, 2005    NaN
# 3  4.0     Friday, January 06, 2006    NaN
# 4  5.0     Friday, January 13, 2006   3:00
#
#                                Location              City Province  \
# 0                             Near Wana  south Waziristan     FATA
# 1          Mir Ali (Near Afghan Border)  North Waziristan     FATA
# 2                   Haisori- Miran Shah  North Waziristan     FATA
# 3  Saidgai village- 115km north of Wana  North Waziristan     FATA
# 4                      Damadola Village    Bajaur  Agency     FATA
#
#    No of Strike  Al-Qaeda  Taliban  Civilians Min  ...  Injured Min  \
# 0           1.0       NaN      1.0            0.0  ...          NaN
# 1           1.0       1.0      NaN            0.0  ...          NaN
# 2           1.0       1.0      NaN            0.0  ...          NaN
# ...

# %%
print(df.isnull().sum())
# Out:
# S#                          1
# Date                        1
# Time                      232
# Location                    3
# City                        1
# Province                    1
# No of Strike                1
# Al-Qaeda                  308
# Taliban                   264
# Civilians Min              69
# Civilians Max              46
# Foreigners Min            312
# Foreigners Max            265
# Total Died Min             97
# Total Died Mix              3
# Injured Min               260
# Injured Max               129
# Women/Children             69
# Special Mention (Site)     75
# Comments                  229
# References                  7
# Longitude                   2
# Latitude                    2
# Temperature(C)              4
# Temperature(F)              4
# dtype: int64

# %%
df.fillna("None",inplace=True)
# Out:
# C:\Users\ghour\AppData\Local\Temp\ipykernel_14256\2303779330.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'None' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna("None",inplace=True)

# %%
# Out:
#     S#                         Date   Time  \
# 0  1.0        Friday, June 18, 2004  22:00
# 1  2.0         Sunday, May 08, 2005  23:30
# 2  3.0  Thursday, December 01, 2005   None
# 3  4.0     Friday, January 06, 2006   None
# 4  5.0     Friday, January 13, 2006   3:00
#
#                                Location              City Province  \
# 0                             Near Wana  south Waziristan     FATA
# 1          Mir Ali (Near Afghan Border)  North Waziristan     FATA
# 2                   Haisori- Miran Shah  North Waziristan     FATA
# 3  Saidgai village- 115km north of Wana  North Waziristan     FATA
# 4                      Damadola Village    Bajaur  Agency     FATA
#
#   No of Strike Al-Qaeda Taliban Civilians Min  ... Injured Min Injured Max  \
# 0          1.0     None     1.0           0.0  ...        None        None
# 1          1.0      1.0    None           0.0  ...        None        None
# ...

# %%
print(df.isnull().sum())
# Out:
# S#                        0
# Date                      0
# Time                      0
# Location                  0
# City                      0
# Province                  0
# No of Strike              0
# Al-Qaeda                  0
# Taliban                   0
# Civilians Min             0
# Civilians Max             0
# Foreigners Min            0
# Foreigners Max            0
# Total Died Min            0
# Total Died Mix            0
# Injured Min               0
# Injured Max               0
# Women/Children            0
# Special Mention (Site)    0
# Comments                  0
# References                0
# Longitude                 0
# Latitude                  0
# Temperature(C)            0
# Temperature(F)            0
# dtype: int64

# %%
city_attack_counts = df.groupby('City')['City'].transform('size')
df['City_with_Total_Attacks'] = df['City'].astype(str) + ' (Total Attacks: ' + city_attack_counts.astype(str) + ')'

# %%
print(df[df['City'] == 'North Waziristan'][['City', 'City_with_Total_Attacks']])
# Out:
#                  City                City_with_Total_Attacks
# 1    North Waziristan  North Waziristan (Total Attacks: 289)
# 2    North Waziristan  North Waziristan (Total Attacks: 289)
# 3    North Waziristan  North Waziristan (Total Attacks: 289)
# 6    North Waziristan  North Waziristan (Total Attacks: 289)
# 7    North Waziristan  North Waziristan (Total Attacks: 289)
# ..                ...                                    ...
# 394  North Waziristan  North Waziristan (Total Attacks: 289)
# 395  North Waziristan  North Waziristan (Total Attacks: 289)
# 397  North Waziristan  North Waziristan (Total Attacks: 289)
# 398  North Waziristan  North Waziristan (Total Attacks: 289)
# 399  North Waziristan  North Waziristan (Total Attacks: 289)
#
# [289 rows x 2 columns]
